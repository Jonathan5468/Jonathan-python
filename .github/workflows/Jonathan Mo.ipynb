# %% [markdown]
# 1) Ejemplos del video 1 de Curso Python para científicos e ingenieros

# %% [markdown]
# Ejemplo 1 Ejercicio

# %%
1+1
# Out:
# 2

# %%
_
# Out:
# 2

# %%
_6
# Out:
# 2

# %% [markdown]
# Tipo numérico

# %%
2 * 4 - (7 - 1)/3 + 1.0
# Out:
# 7.0

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# Error dividir entre cero

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-9e1622b385b6> in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Forzar una división entera

# %%
3//2
# Out:
# 1

# %% [markdown]
# Números complejos

# %%
2 + 3j
# Out:
# (2+3j)

# %%
1j
# Out:
# 1j

# %%
abs( 3 + 2j)
# Out:
# 3.605551275463989

# %%
(3 + 2j) * (1 - 1j)
# Out:
# (5-1j)

# %%
1j**2
# Out:
# (-1+0j)

# %% [markdown]
# Para convertir tipos numéricos podemos usar las funciones int, float, complex

# %%
_16
# Out:
# 3.605551275463989

# %%
int(_)
# Out:
# 3

# %%
round(_19)
# Out:
# 4

# %%
float(_)
# Out:
# 3.0

# %%
complex(_)
# Out:
# (3+0j)

# %% [markdown]
# Función máximo y mínimo

# %%
max(0 , -1 , 1 , 2)
# Out:
# 2

# %%
min(1 , 2 , 0 , -1 )
# Out:
# -1

# %% [markdown]
# Asignación y operadores de comparación

# %% [markdown]
# Ejercicios de la APE 1

# %% [markdown]
# Calcular la conductividad térmica de un producto alimenticio desarrollado para suplir necesidades energéticas, el cual (alimento) tiene una composición de 90% de agua, 7% de carbohidratos, 1.5% de proteína, 0.5 de cenizas y 0 % de grasa.

# %%
Xc= 7/100
Xp= 1.5/100
Xf= 0/100
Xa= 0.5/100
Xw= 90/100
K= ( 0.25*Xc + 0.155*Xp + 0.16*Xf + 0.135*Xa + 0.58*Xw)
print("El valor de la conductividad térmica del producto es",K)
# Out:
# El valor de la conductividad térmica del producto es 0.5425

# %% [markdown]
# Calcular la conductividad térmica de pure de vegateles con 92% de agua.

# %%
Xw= 92/100
K= 0.148 + 0.493*Xw
print("El valor de la conductividad térmica del pures es",K)
# Out:
# El valor de la conductividad térmica del pures es 0.60156

# %% [markdown]
# Calcular la conductividad térmica de un alimento líquido a base de leche, si la temperatura (T) = 25°C

# %%
T= 25
Xw= 98/100
K= ( 326.8 + 1.0413*T - 0.00337*T**2)*(0.44 + 0.54*Xw)*1.73e-3
print("El valor de la conduvtividad térmica es",K)
# Out:
# El valor de la conduvtividad térmica es 0.588068314995
